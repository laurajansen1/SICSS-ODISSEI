# %%
import pandas as pd
# %matplotlib inline
summerschooldata = pd.read_csv("data_subsample.csv")

# Checking data, summarizing etc.
print(type(summerschooldata))
summerschooldata.head()
df_summerschooldata_some_cols = pd.read_csv("data_subsample.csv", usecols= [0,1,2])
print(df_summerschooldata_some_cols.shape)
print(df_summerschooldata_some_cols.columns)
df_summerschooldata_some_cols = pd.read_csv("data_subsample.csv", usecols= ['nomem_encr', 'cf19l_m', 'cf19l390'])
print(df_summerschooldata_some_cols.columns)
print(summerschooldata.nomem_encr)
print(summerschooldata[['nomem_encr', 'cf19l_m']])
df_summerschooldata_some_rows = summerschooldata[1:4]
summerschooldata_some_rows = summerschooldata[(summerschooldata.cf19l_m == 201909) & summerschooldata.nomem_encr == 53334]
summerschooldata.describe()
summerschooldata['cf19l_m'].describe() # summarize one value
print(summerschooldata['cf19l_m'].min()) # minimum value
summerschooldata['nomem_encr'].isnull().sum() # sum missing values per variable

# Histogram
summerschooldata['cf19l393'].hist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (1000, 3)
# Index(['nomem_encr', 'cf19l_m', 'cf19l390'], dtype='object')
# Index(['nomem_encr', 'cf19l_m', 'cf19l390'], dtype='object')
# 0      53334
# 1      53334
# 2      53337
# 3      53337
# 4      53339
#        ...
# 995    54573
# 996    54576
# 997    54576
# 998    54577
# 999    54577
# Name: nomem_encr, Length: 1000, dtype: int64
#      nomem_encr  cf19l_m
# 0         53334   201909
# 1         53334   201909
# 2         53337   201909
# 3         53337   201909
# 4         53339   201909
# ..          ...      ...
# 995       54573   201909
# 996       54576   201910
# 997       54576   201909
# 998       54577   201910
# 999       54577   201909
#
# [1000 rows x 2 columns]
# 201909
# <Axes: >
